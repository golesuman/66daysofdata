# %% [markdown]
# <a href="https://colab.research.google.com/github/golesuman/66daysofdata/blob/main/Day66/catanddogdetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -L "https://public.roboflow.com/ds/QZHHxT9PyB?key=8tVUKW551V" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/japanese_chin_149_jpg.rf.ea729719e1f68fba3722c54c52258fb5.jpg
#  extracting: train/images/japanese_chin_14_jpg.rf.a4a12b7fb1137f8d46e2a207028683af.jpg
#  extracting: train/images/japanese_chin_150_jpg.rf.f9accdf4140d23522dddc68e07b4a74b.jpg
#  extracting: train/images/japanese_chin_151_jpg.rf.1dd50b6e45a27083c461ceadd618e4b6.jpg
#  extracting: train/images/japanese_chin_152_jpg.rf.394cb1a0af1a2b9caf4bba91480ee5dd.jpg
#  extracting: train/images/japanese_chin_155_jpg.rf.b4c71c79a6be904f80096f2a547b5dd9.jpg
#  extracting: train/images/japanese_chin_156_jpg.rf.ac9efaa75a5b4a8c1e6e36a3260c3050.jpg
#  extracting: train/images/japanese_chin_157_jpg.rf.6aaddf389a9c6c80dc81698e096527a7.jpg
#  extracting: train/images/japanese_chin_158_jpg.rf.d7386ee83518f747128fd5578f4b4f06.jpg
#  extracting: train/images/japanese_chin_15_jpg.rf.5238d247595938ebb902bfbf81a971a5.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-25-gcaf7ad0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.4/78.2 GB disk)

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 10 --data /content/data.yaml --weights yolov5s.pt --cache
# Out:
# ...
# train: weights=yolov5s.pt, cfg=, data=/content/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-25-gcaf7ad0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/catanddog.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/catanddog.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-25-gcaf7ad0 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/682) /content/catanddog.mp4: 640x384 Done. (0.028s)
# video 1/1 (2/682) /content/catanddog.mp4: 640x384 Done. (0.028s)
# video 1/1 (3/682) /content/catanddog.mp4: 640x384 Done. (0.028s)
# video 1/1 (4/682) /content/catanddog.mp4: 640x384 Done. (0.028s)
# video 1/1 (5/682) /content/catanddog.mp4: 640x384 Done. (0.028s)
# ...
