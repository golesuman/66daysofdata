# %% [markdown]
# <a href="https://colab.research.google.com/github/golesuman/66daysofdata/blob/main/Day64/customfacedetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-17-g596de6d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.2/78.2 GB disk)

# %%
# !unzip train_data.zip
# Out:
# Archive:  train_data.zip
#    creating: train_data/
#    creating: train_data/images/
#    creating: train_data/images/train/
#   inflating: train_data/images/train/18.jpg
#   error:  invalid compressed data to inflate
# file #5:  bad zipfile offset (local header sig):  2676142
#   inflating: train_data/images/train/20.jpg
#   inflating: train_data/images/train/12.jpg
#   inflating: train_data/images/train/15.jpg
#   inflating: train_data/images/train/4.jpg
#   inflating: train_data/images/train/3.jpg
#   inflating: train_data/images/train/19.jpg
#   inflating: train_data/images/train/11.jpg
#   inflating: train_data/images/train/2.jpg
#   inflating: train_data/images/train/7.jpg
#   inflating: train_data/images/train/6.jpg
#   inflating: train_data/images/train/5.jpg
#   inflating: train_data/images/train/8.jpg
#   inflating: train_data/images/train/14.jpg
#   inflating: train_data/images/train/9.jpg
#   inflating: train_data/images/train/13.jpg
# ...

# %%
# !python train.py --img 640 --batch 2 --epochs 50 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-17-g596de6d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp8/weights/last.pt --img 640 --conf 0.25 --source ../elon.mp4
# Out:
# detect: weights=['runs/train/exp8/weights/best.pt'], source=../elon.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-17-g596de6d torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/3046) /content/elon.mp4: 384x640 Done. (0.027s)
# video 1/1 (2/3046) /content/elon.mp4: 384x640 Done. (0.027s)
# video 1/1 (3/3046) /content/elon.mp4: 384x640 Done. (0.027s)
# video 1/1 (4/3046) /content/elon.mp4: 384x640 Done. (0.026s)
# video 1/1 (5/3046) /content/elon.mp4: 384x640 Done. (0.026s)
# ...
