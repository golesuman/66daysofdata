# %% [markdown]
# <a href="https://colab.research.google.com/github/golesuman/66daysofdata/blob/main/filterkernels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img=cv2.imread('cityhall.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
img_copy=np.copy(img)
gray_img=cv2.cvtColor(img_copy,cv2.COLOR_RGB2GRAY)
plt.imshow(gray_img,cmap='gray')

# %%
kernel=np.array([[-1,0,1],
                 [-2,0,2],
                 [-1,0,1]])
filter_img=cv2.filter2D(gray_img,-1,kernel)
fig,axes=plt.subplots(2,1,figsize=(10,10))
axes[0].imshow(kernel,cmap='gray')
axes[0].set_title('Filter')
axes[1].imshow(filter_img,cmap='gray')
axes[1].set_title('Filtered Image')
# Out:
# Text(0.5, 1.0, 'Filtered Image')

# %%
#creating binary Image
retval, binary_img=cv2.threshold(filter_img,100,255,cv2.THRESH_BINARY)

# %%
plt.imshow(binary_img,cmap='gray')

# %%
hori_filter=np.array([[-1,0,1],
                      [0,0,0],
                      [-2,0,2]])
hori_filtered=cv2.filter2D(gray_img,-1,hori_filter)
plt.imshow(hori_filtered,cmap='gray')

# %%
new_img=hori_filtered[:,400:1000] #cropping the image
plt.imshow(new_img,cmap='gray')
